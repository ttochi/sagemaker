# %% [markdown]
# # SageMaker Marketplace Algorithm
#
# - Various external vendors are selling SageMaker Algorithm through AWS Marketplace.
#
# ## Example Code
# The model used for this example is `Autogluon`, one of marketplace algorithm.
#
# #### Training is done in the following order:
# 1. Subscribe algorithm in Marketplace
# 2. Build development environment
# 3. Prepare input data
# 4. Run training job
# 5. Deploy saved model

# %% [markdown]
# ## 1. Subscribe algorithm in Marketplace
#
# Go to [AWS marketplace](https://aws.amazon.com/marketplace/search/results?page=1&filters=fulfillment_options%2Cresource_type&fulfillment_options=SAGEMAKER&resource_type=ALGORITHM) and subscribe `Autoglon` algorithm.
#
# After the subscription, we can get algorithm ARN info in [here](https://ap-northeast-2.console.aws.amazon.com/sagemaker/home?region=ap-northeast-2#/algorithms/my-subscriptions).

# %% [markdown]
# ## 2. Build development environment
#
# #### Set up the Notebook environment
# - instance spec: ml.t3.medium (2vCPU + 4GB)
# - kernel image: Python 3 (Data Science)

# %% [markdown]
# ## 3. Prepare input data
#
# #### Download the dataset
#
# I have previously downloaded the dataset in the `./data/bank-additional-full.csv`.<br>
# And pre-process the data and upload to object storage.

# %%
import pandas as pd

data = pd.read_csv("./data/bank-additional-full.csv", sep=';')

# Split train/test data
train = data.sample(frac=0.7, random_state=42)
test = data.drop(train.index)

train.head()
# Out:
#        age          job  marital    education  default housing loan  \
# 32884   57   technician  married  high.school       no      no  yes
# 3169    55      unknown  married      unknown  unknown     yes   no
# 32206   33  blue-collar  married     basic.9y       no      no   no
# 9403    36       admin.  married  high.school       no      no   no
# 14020   27    housemaid  married  high.school       no     yes   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 32884   cellular   may         mon  ...         1    999         1
# 3169   telephone   may         thu  ...         2    999         0
# 32206   cellular   may         fri  ...         1    999         1
# 9403   telephone   jun         fri  ...         4    999         0
# 14020   cellular   jul         fri  ...         2    999         0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 32884      failure         -1.8          92.893          -46.2      1.299
# 3169   nonexistent          1.1          93.994          -36.4      4.860
# 32206      failure         -1.8          92.893          -46.2      1.313
# 9403   nonexistent          1.4          94.465          -41.8      4.967
# 14020  nonexistent          1.4          93.918          -42.7      4.963
#
#        nr.employed   y
# 32884       5099.1  no
# 3169        5191.0  no
# 32206       5099.1  no
# 9403        5228.1  no
# 14020       5228.1  no
#
# [5 rows x 21 columns]

# %%
import sagemaker

sagemaker_session = sagemaker.Session()

train.to_csv("train.csv", index=False)
train_s3_path = sagemaker_session.upload_data("train.csv", 
                                              bucket=sagemaker_session.default_bucket(), 
                                              key_prefix="data/bank")

print(train_s3_path)
# Out:
# s3://sagemaker-ap-northeast-2-834160605896/data/bank/train.csv

# %% [markdown]
# ## 4. Run training job
#
# #### Define training job spec
#
# Import `AlgorithmEstimator` object from sagemaker SDK.<br>
# Pass the subscribing algorithm ARN.

# %%
import sagemaker
from sagemaker.algorithm import AlgorithmEstimator

# Define job specs
algorithm_arn = "arn:aws:sagemaker:ap-northeast-2:745090734665:algorithm/autogluon-tabular-v3-5-cb7001bd0e8243b50adc3338deb44a48"
job_name = "DEMO-marketplace"
instance_type = "ml.m5.4xlarge"

algo = AlgorithmEstimator(
    algorithm_arn=algorithm_arn,
    role=sagemaker.get_execution_role(),
    base_job_name=job_name,
    instance_count=1,
    instance_type=instance_type,
    hyperparameters={
        "init_args": {"label": "y"},
        "fit_args": { "presets": ["optimize_for_deployment"] },
        "feature_importance": True}
)

algo.fit({"training": train_s3_path})
# Out:
# 2021-06-27 11:40:38 Starting - Starting the training job...
# 2021-06-27 11:40:40 Starting - Launching requested ML instancesProfilerReport-1624794038: InProgress
# ......
# 2021-06-27 11:41:47 Starting - Preparing the instances for training...
# 2021-06-27 11:42:35 Downloading - Downloading input data...
# 2021-06-27 11:42:53 Training - Downloading the training image.........
# 2021-06-27 11:44:34 Training - Training image download completed. Training in progress..2021-06-27 11:44:34,720 sagemaker-training-toolkit INFO     Imported framework sagemaker_mxnet_container.training
# 2021-06-27 11:44:34,723 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-06-27 11:44:34,723 sagemaker-training-toolkit INFO     Failed to parse hyperparameter init_args value {'label': 'y'} to Json.
# Returning the value itself
# 2021-06-27 11:44:34,723 sagemaker-training-toolkit INFO     Failed to parse hyperparameter fit_args value {'presets': ['optimize_for_deployment']} to Json.
# Returning the value itself
# 2021-06-27 11:44:34,723 sagemaker-training-toolkit INFO     Failed to parse hyperparameter feature_importance value True to Json.
# Returning the value itself
# 2021-06-27 11:44:34,735 sagemaker_mxnet_container.training INFO     MXNet training environment: {'SM_HOSTS': '["algo-1"]', 'SM_NETWORK_INTERFACE_NAME': 'eth0', 'SM_HPS': '{"feature_importance":"True","fit_args":"{\'presets\': [\'optimize_for_deployment\']}","init_args":"{\'label\': \'y\'}"}', 'SM_USER_ENTRY_POINT': 'train.py', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}', 'SM_INPUT_DATA_CONFIG': '{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_CHANNELS': '["training"]', 'SM_CURRENT_HOST': 'algo-1', 'SM_MODULE_NAME': 'train', 'SM_LOG_LEVEL': '20', 'SM_FRAMEWORK_MODULE': 'sagemaker_mxnet_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_INPUT_CONFIG_DIR': '/opt/ml/input/config', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_NUM_CPUS': '16', 'SM_NUM_GPUS': '0', 'SM_MODEL_DIR': '/opt/ml/model', 'SM_MODULE_DIR': '/opt/ml/code', 'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_mxnet_container.training:main","hosts":["algo-1"],"hyperparameters":{"feature_importance":"True","fit_args":"{\'presets\': [\'optimize_for_deployment\']}","init_args":"{\'label\': \'y\'}"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"DEMO-marketplace-2021-06-27-11-40-38-207","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"train","network_interface_name":"eth0","num_cpus":16,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}', 'SM_USER_ARGS': '["--feature_importance","True","--fit_args","{\'presets\': [\'optimize_for_deployment\']}","--init_args","{\'label\': \'y\'}"]', 'SM_OUTPUT_INTERMEDIATE_DIR': '/opt/ml/output/intermediate', 'SM_CHANNEL_TRAINING': '/opt/ml/input/data/training', 'SM_HP_INIT_ARGS': "{'label': 'y'}", 'SM_HP_FIT_ARGS': "{'presets': ['optimize_for_deployment']}", 'SM_HP_FEATURE_IMPORTANCE': 'True'}
# 2021-06-27 11:44:34,737 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-06-27 11:44:34,737 sagemaker-training-toolkit INFO     Failed to parse hyperparameter init_args value {'label': 'y'} to Json.
# Returning the value itself
# 2021-06-27 11:44:34,737 sagemaker-training-toolkit INFO     Failed to parse hyperparameter fit_args value {'presets': ['optimize_for_deployment']} to Json.
# Returning the value itself
# 2021-06-27 11:44:34,738 sagemaker-training-toolkit INFO     Failed to parse hyperparameter feature_importance value True to Json.
# Returning the value itself
# 2021-06-27 11:44:40,984 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-06-27 11:44:40,984 sagemaker-training-toolkit INFO     Failed to parse hyperparameter init_args value {'label': 'y'} to Json.
# Returning the value itself
# 2021-06-27 11:44:40,985 sagemaker-training-toolkit INFO     Failed to parse hyperparameter fit_args value {'presets': ['optimize_for_deployment']} to Json.
# Returning the value itself
# 2021-06-27 11:44:40,985 sagemaker-training-toolkit INFO     Failed to parse hyperparameter feature_importance value True to Json.
# Returning the value itself
# 2021-06-27 11:44:40,997 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-06-27 11:44:40,998 sagemaker-training-toolkit INFO     Failed to parse hyperparameter init_args value {'label': 'y'} to Json.
# Returning the value itself
# 2021-06-27 11:44:40,998 sagemaker-training-toolkit INFO     Failed to parse hyperparameter fit_args value {'presets': ['optimize_for_deployment']} to Json.
# Returning the value itself
# 2021-06-27 11:44:40,998 sagemaker-training-toolkit INFO     Failed to parse hyperparameter feature_importance value True to Json.
# Returning the value itself
# 2021-06-27 11:44:41,009 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_mxnet_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "init_args": "{'label': 'y'}",
#         "fit_args": "{'presets': ['optimize_for_deployment']}",
#         "feature_importance": "True"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "DEMO-marketplace-2021-06-27-11-40-38-207",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "/opt/ml/code",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 16,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"feature_importance":"True","fit_args":"{'presets': ['optimize_for_deployment']}","init_args":"{'label': 'y'}"}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_mxnet_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=16
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=/opt/ml/code
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_mxnet_container.training:main","hosts":["algo-1"],"hyperparameters":{"feature_importance":"True","fit_args":"{'presets': ['optimize_for_deployment']}","init_args":"{'label': 'y'}"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"DEMO-marketplace-2021-06-27-11-40-38-207","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"train","network_interface_name":"eth0","num_cpus":16,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--feature_importance","True","--fit_args","{'presets': ['optimize_for_deployment']}","--init_args","{'label': 'y'}"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_INIT_ARGS={'label': 'y'}
# SM_HP_FIT_ARGS={'presets': ['optimize_for_deployment']}
# SM_HP_FEATURE_IMPORTANCE=True
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python36.zip:/usr/local/lib/python3.6:/usr/local/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /usr/local/bin/python3.6 train.py --feature_importance True --fit_args {'presets': ['optimize_for_deployment']} --init_args {'label': 'y'}
#
#
# /opt/ml/input:
# total 8
# drwxr-xr-x 2 root root 4096 Jun 27 11:42 config
# drwxr-xr-x 3 root root 4096 Jun 27 11:42 data
#
# /opt/ml/input/config:
# total 32
# -rw-r--r-- 1 root root  112 Jun 27 11:42 hyperparameters.json
# -rw-r--r-- 1 root root  513 Jun 27 11:42 init-config.json
# -rw-r--r-- 1 root root  107 Jun 27 11:42 inputdataconfig.json
# -rw-r--r-- 1 root root   80 Jun 27 11:42 metric-definition-regex.json
# -rw-r--r-- 1 root root  207 Jun 27 11:42 profilerconfig.json
# -rw-r--r-- 1 root root   81 Jun 27 11:42 resourceconfig.json
# -rw-r--r-- 1 root root 1486 Jun 27 11:42 trainingjobconfig.json
# -rw-r--r-- 1 root root    2 Jun 27 11:42 upstreamoutputdataconfig.json
#
# /opt/ml/input/data:
# total 8
# drwxr-xr-x 2 root root 4096 Jun 27 11:42 training
# -rw-r--r-- 1 root root   83 Jun 27 11:42 training-manifest
#
# /opt/ml/input/data/training:
# total 3520
# -rw-r--r-- 1 root root 3602547 Jun 27 11:42 train.csv
# INFO:root:0
# IPython could not be loaded!
# DEBUG:asyncio:Using selector: EpollSelector
# fit_args:
# presets,  type: <class 'list'>,  value: ['optimize_for_deployment']
# Train files: ['train.csv']
# WARNING:autogluon.core.utils.utils:Warning: path already exists! This predictor may overwrite an existing predictor! path="/opt/ml/model"
# INFO:root:Presets specified: ['optimize_for_deployment']
# INFO:autogluon.tabular.learner.default_learner:Beginning AutoGluon training ...
# INFO:autogluon.tabular.learner.default_learner:AutoGluon will save models to "/opt/ml/model/"
# INFO:autogluon.tabular.learner.default_learner:AutoGluon Version:  0.1.0
# INFO:autogluon.tabular.learner.default_learner:Train Data Rows:    28832
# INFO:autogluon.tabular.learner.default_learner:Train Data Columns: 20
# INFO:autogluon.tabular.learner.default_learner:Preprocessing data ...
# Level 25:autogluon.core.utils.utils:AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# INFO:autogluon.core.utils.utils:#0112 unique label values:  ['no', 'yes']
# Level 25:autogluon.core.utils.utils:#011If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# INFO:numexpr.utils:Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:autogluon.core.data.label_cleaner:Selected class <--> label mapping:  class 1 = yes, class 0 = no
# INFO:autogluon.core.data.label_cleaner:#011Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (yes) vs negative (no) class.
# #011To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# INFO:autogluon.tabular.learner.default_learner:Using Feature Generators to preprocess the data ...
# INFO:autogluon.features.generators.abstract:Fitting AutoMLPipelineFeatureGenerator...
# INFO:autogluon.features.generators.abstract:#011Available Memory:                    64265.37 MB
# INFO:autogluon.features.generators.abstract:#011Train Data (Original)  Memory Usage: 20.51 MB (0.0% of available memory)
# INFO:autogluon.features.generators.abstract:#011Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# INFO:autogluon.features.generators.abstract:#011Stage 1 Generators:
# INFO:autogluon.features.generators.abstract:#011#011Fitting AsTypeFeatureGenerator...
# INFO:autogluon.features.generators.abstract:#011Stage 2 Generators:
# INFO:autogluon.features.generators.abstract:#011#011Fitting FillNaFeatureGenerator...
# INFO:autogluon.features.generators.abstract:#011Stage 3 Generators:
# INFO:autogluon.features.generators.abstract:#011#011Fitting IdentityFeatureGenerator...
# INFO:autogluon.features.generators.abstract:#011#011Fitting CategoryFeatureGenerator...
# INFO:autogluon.features.generators.abstract:#011#011#011Fitting CategoryMemoryMinimizeFeatureGenerator...
# INFO:autogluon.features.generators.abstract:#011Stage 4 Generators:
# INFO:autogluon.features.generators.abstract:#011#011Fitting DropUniqueFeatureGenerator...
# INFO:autogluon.features.generators.abstract:#011Types of features in original data (raw dtype, special dtypes):
# INFO:autogluon.core.features.feature_metadata:#011#011('float', [])  :  5 | ['emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']
# INFO:autogluon.core.features.feature_metadata:#011#011('int', [])    :  5 | ['age', 'duration', 'campaign', 'pdays', 'previous']
# INFO:autogluon.core.features.feature_metadata:#011#011('object', []) : 10 | ['job', 'marital', 'education', 'default', 'housing', ...]
# INFO:autogluon.features.generators.abstract:#011Types of features in processed data (raw dtype, special dtypes):
# INFO:autogluon.core.features.feature_metadata:#011#011('category', []) : 10 | ['job', 'marital', 'education', 'default', 'housing', ...]
# INFO:autogluon.core.features.feature_metadata:#011#011('float', [])    :  5 | ['emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']
# INFO:autogluon.core.features.feature_metadata:#011#011('int', [])      :  5 | ['age', 'duration', 'campaign', 'pdays', 'previous']
# INFO:autogluon.features.generators.abstract:#0110.2s = Fit runtime
# INFO:autogluon.features.generators.abstract:#01120 features in original data used to generate 20 features in processed data.
# INFO:autogluon.features.generators.abstract:#011Train Data (Processed) Memory Usage: 2.6 MB (0.0% of available memory)
# INFO:autogluon.tabular.learner.default_learner:Data preprocessing and feature engineering runtime = 0.28s ...
# Level 25:autogluon.tabular.trainer.abstract_trainer:AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# INFO:autogluon.tabular.trainer.abstract_trainer:#011To change this, specify the eval_metric argument of fit()
# INFO:autogluon.tabular.trainer.auto_trainer:Automatically generating train/validation split with holdout_frac=0.08670921198668147, Train Rows: 26332, Val Rows: 2500
# INFO:autogluon.tabular.trainer.abstract_trainer:Fitting model: RandomForestGini ...
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.9172#011 = Validation accuracy score
# INFO:autogluon.tabular.trainer.abstract_trainer:#0111.26s#011 = Training runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.22s#011 = Validation runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:Fitting model: RandomForestEntr ...
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.9208#011 = Validation accuracy score
# INFO:autogluon.tabular.trainer.abstract_trainer:#0111.25s#011 = Training runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.22s#011 = Validation runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:Fitting model: ExtraTreesGini ...
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.9112#011 = Validation accuracy score
# INFO:autogluon.tabular.trainer.abstract_trainer:#0111.05s#011 = Training runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.22s#011 = Validation runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:Fitting model: ExtraTreesEntr ...
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.9112#011 = Validation accuracy score
# INFO:autogluon.tabular.trainer.abstract_trainer:#0111.16s#011 = Training runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.22s#011 = Validation runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:Fitting model: KNeighborsUnif ...
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.9048#011 = Validation accuracy score
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.23s#011 = Training runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.11s#011 = Validation runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:Fitting model: KNeighborsDist ...
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.9032#011 = Validation accuracy score
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.23s#011 = Training runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.11s#011 = Validation runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:Fitting model: LightGBM ...
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.9252#011 = Validation accuracy score
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.58s#011 = Training runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.02s#011 = Validation runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:Fitting model: LightGBMXT ...
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.9244#011 = Validation accuracy score
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.41s#011 = Training runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.02s#011 = Validation runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:Fitting model: CatBoost ...
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.924#011 = Validation accuracy score
# INFO:autogluon.tabular.trainer.abstract_trainer:#0112.29s#011 = Training runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.02s#011 = Validation runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:Fitting model: XGBoost ...
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.9264#011 = Validation accuracy score
# INFO:autogluon.tabular.trainer.abstract_trainer:#0111.09s#011 = Training runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.03s#011 = Validation runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:Fitting model: NeuralNetMXNet ...
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.9236#011 = Validation accuracy score
# INFO:autogluon.tabular.trainer.abstract_trainer:#01143.67s#011 = Training runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.23s#011 = Validation runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:Fitting model: NeuralNetFastAI ...
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.9212#011 = Validation accuracy score
# INFO:autogluon.tabular.trainer.abstract_trainer:#01146.67s#011 = Training runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.24s#011 = Validation runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:Fitting model: LightGBMLarge ...
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.9248#011 = Validation accuracy score
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.84s#011 = Training runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.02s#011 = Validation runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:Fitting model: WeightedEnsemble_L2 ...
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.9308#011 = Validation accuracy score
# INFO:autogluon.tabular.trainer.abstract_trainer:#0111.4s#011 = Training runtime
# INFO:autogluon.tabular.trainer.abstract_trainer:#0110.01s#011 = Validation runtime
# INFO:autogluon.tabular.learner.default_learner:AutoGluon training complete, total runtime = 108.17s ...
# WARNING:autogluon.core.models.abstract.abstract_model:Deleting model ExtraTreesGini. All files under /opt/ml/model/models/ExtraTreesGini/ will be removed.
# WARNING:autogluon.core.models.abstract.abstract_model:Deleting model KNeighborsDist. All files under /opt/ml/model/models/KNeighborsDist/ will be removed.
# INFO:root:TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/opt/ml/model/")
# █#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015█#015*** Summary of fit() ***
# Estimated performance of each model:
#                   model  score_val  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   WeightedEnsemble_L2     0.9308       1.356039  100.852398                0.005909           1.401407            2       True         12
# 1               XGBoost     0.9264       0.034948    1.087018                0.034948           1.087018            1       True          8
# 2              LightGBM     0.9252       0.019932    0.579556                0.019932           0.579556            1       True          5
# 3         LightGBMLarge     0.9248       0.021647    0.842400                0.021647           0.842400            1       True         11
# 4            LightGBMXT     0.9244       0.021787    0.414181                0.021787           0.414181            1       True          6
# 5              CatBoost     0.9240       0.020785    2.285721                0.020785           2.285721            1       True          7
# 6        NeuralNetMXNet     0.9236       0.233887   43.669623                0.233887          43.669623            1       True          9
# 7       NeuralNetFastAI     0.9212       0.238084   46.673339                0.238084          46.673339            1       True         10
# 8      RandomForestEntr     0.9208       0.215687    1.250079                0.215687           1.250079            1       True          2
# 9      RandomForestGini     0.9172       0.216531    1.258984                0.216531           1.258984            1       True          1
# 10       ExtraTreesEntr     0.9112       0.216738    1.158480                0.216738           1.158480            1       True          3
# 11       KNeighborsUnif     0.9048       0.110104    0.231613                0.110104           0.231613            1       True          4
# Number of models trained: 12
# Types of models trained:
# {'RFModel', 'TabularNeuralNetModel', 'KNNModel', 'CatBoostModel', 'NNFastAiTabularModel', 'LGBModel', 'XTModel', 'WeightedEnsembleModel', 'XGBoostModel'}
# Bagging used: False
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', []) : 10 | ['job', 'marital', 'education', 'default', 'housing', ...]
# ('float', [])    :  5 | ['emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']
# ('int', [])      :  5 | ['age', 'duration', 'campaign', 'pdays', 'previous']
# Plot summary of models saved to file: /opt/ml/model/SummaryOfModels.html
# *** End of fit() summary ***
# Warning: using box for unknown shape rectagle
#
# Model export summary:
# /opt/ml/model/: ['learner.pkl', 'models', 'predictor.pkl', 'SummaryOfModels.html']
# /opt/ml/model/models: ['KNeighborsUnif', 'LightGBMXT', 'RandomForestGini', 'RandomForestEntr', 'trainer.pkl', 'NeuralNetMXNet', 'XGBoost', 'ExtraTreesEntr', 'CatBoost', 'LightGBMLarge', 'NeuralNetFastAI', 'LightGBM', 'WeightedEnsemble_L2']
# /opt/ml/model directory size: 405M
#
# Elapsed time: 111.805 seconds. Training Completed!
# 2021-06-27 11:46:42,569 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2021-06-27 11:46:54 Uploading - Uploading generated training model
# 2021-06-27 11:47:35 Completed - Training job completed
# ProfilerReport-1624794038: NoIssuesFound
# Training seconds: 285
# Billable seconds: 285

# %% [markdown]
# ## 5. Deploy saved models
#
# #### Deploy saved model
# After a training, we can host the created model in SageMaker.
# After create inference endpoint, we can check the API url.

# %%
from sagemaker.serializers import CSVSerializer
from sagemaker.deserializers import StringDeserializer

predictor = algo.deploy(
    initial_instance_count=1,
    instance_type="ml.m5.4xlarge",
    serializer=CSVSerializer(),
    deserializer=StringDeserializer(),
)
# Out:
# ..........
# ---------------!

# %% [markdown]
# #### Invoke inference API

# %%
import numpy as np
from collections import Counter
from sklearn.metrics import accuracy_score

results = predictor.predict(test.to_csv(index=False)).splitlines()

# Check output
y_results = np.array([i.split(",")[0] for i in results])

print(Counter(y_results))

print("accuracy: {}".format(accuracy_score(y_true=test["y"], y_pred=y_results)))
# Out:
# Counter({'no': 11318, 'yes': 1038})
# accuracy: 0.9187439300744578
